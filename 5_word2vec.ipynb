# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('Sample data words')
for i in data[:10]:
    print('\t{}'.format(reverse_dictionary[i]))
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3083, 12, 6, 195, 2, 3137, 46, 59, 156]
# Sample data words
# anarchism
# originated
# as
# a
# term
# of
# abuse
# first
# used
# against

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    #print('buffer:',buffer)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

#print('data:', [reverse_dictionary[di] for di in data[:8]])


batch, labels = generate_batch(batch_size=8, num_skips=4, skip_window=2)
print(batch)
print(labels)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
#for num_skips, skip_window in [(2, 1), (4, 2)]:
#    data_index = 0
#    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
#    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#    print('    batch:', [reverse_dictionary[bi] for bi in batch])
#    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# [12 12 12 12  6  6  6  6]
# [[3083]
#  [   6]
#  [5242]
#  [ 195]
#  [3083]
#  [  12]
#  [   2]
#  [ 195]]
# 12 as -> 3083 originated
# 12 as -> 6 a
# 12 as -> 5242 anarchism
# 12 as -> 195 term
# 6 a -> 3083 originated
# 6 a -> 12 as
# 6 a -> 2 of
# 6 a -> 195 term

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
tf.nn.embedding_lookup?

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.921216
# Nearest to so: latency, widgery, asleep, hostilities, respondents, essay, sophomore, confines,
# Nearest to he: quicksilver, islam, borrows, locations, desertification, curtin, piazza, buson,
# Nearest to may: ceti, perlman, ninety, bc, talent, registering, employees, latvian,
# Nearest to years: talisman, trees, dysfunctional, justice, northside, divergences, dissent, mint,
# Nearest to nine: stenella, fat, ixion, modifies, ranching, wolfhounds, tempestuous, extracts,
# Nearest to war: isdn, education, lon, maharal, panther, precipitate, daunting, abandoned,
# Nearest to can: feuding, treatise, foreseeable, steals, pathways, grissom, nomen, dudayev,
# Nearest to american: interface, warmed, soups, kis, incantations, ferris, mic, rhondda,
# Nearest to states: progression, latvia, wrigley, fleury, tbs, markus, doubleday, aristocratic,
# Nearest to after: moveable, stalks, progressivism, numan, logie, entrenchment, adorno, cromwell,
# Nearest to four: compositing, mycenean, daddah, wealthier, keane, rabba, ailing, mistresses,
# Nearest to use: nitrite, facing, plenary, mystery, rutherford, heston, seldom, what,
# Nearest to world: bureaucrats, assimilation, guoyu, precipitates, lifestyles, bil, cautions, baptisms,
# Nearest to which: undergone, rationalization, dwarfed, newsstand, crimea, ferrand, catapulted, drachma,
# Nearest to there: retold, insuring, rightmost, precluded, mellows, sentiments, aggressively, whedon,
# Nearest to state: ten, gabor, baronet, quatrain, celesta, institutions, nad, aquarius,
# Average loss at step 2000: 4.357319
# Average loss at step 4000: 3.862008
# Average loss at step 6000: 3.788666
# Average loss at step 8000: 3.685823
# Average loss at step 10000: 3.612702
# Nearest to so: widgery, why, essay, suppliers, befriends, coordinator, latency, shepherd,
# Nearest to he: it, they, she, there, never, who, crossed, cutaway,
# Nearest to may: can, ceti, talent, could, would, bobo, bc, vinod,
# Nearest to years: talisman, dysfunctional, legality, justice, trees, chording, clements, lizzy,
# Nearest to nine: eight, six, seven, five, zero, four, three, two,
# Nearest to war: isdn, lon, panther, education, abandoned, cia, gehenna, hydrophobic,
# Nearest to can: may, must, should, would, mace, could, kullervo, treatise,
# Nearest to american: and, maxime, warmed, bundesl, interface, appleby, disarming, kis,
# Nearest to states: morbidity, progression, aristocratic, pueblo, fleury, full, match, legislator,
# Nearest to after: in, when, into, bertie, landline, unknowns, of, around,
# Nearest to four: six, seven, three, five, eight, nine, two, zero,
# Nearest to use: nitrite, seldom, facing, what, mystery, tones, bethune, interception,
# Nearest to world: transformation, bil, assimilation, precipitates, senna, carleton, bureaucrats, map,
# Nearest to which: that, who, also, this, it, garbage, drachma, crimea,
# Nearest to there: it, he, they, meander, resolver, not, retold, sentiments,
# Nearest to state: gabor, extravagant, institutions, buber, satchmo, baronet, inexperience, modernised,
# Average loss at step 12000: 3.601964
# Average loss at step 14000: 3.571843
# Average loss at step 16000: 3.407607
# Average loss at step 18000: 3.454056
# Average loss at step 20000: 3.540374
# Nearest to so: cadet, impressionists, befriends, pronounce, delete, lichfield, why, essay,
# Nearest to he: it, she, they, who, there, never, which, unlikely,
# Nearest to may: can, could, would, should, will, cannot, must, might,
# Nearest to years: justice, talisman, dysfunctional, chording, lbs, massawa, polycrates, differentiate,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to war: lon, isdn, panther, cia, worthy, varela, mira, abandoned,
# Nearest to can: may, must, could, would, should, will, might, cannot,
# Nearest to american: british, and, german, dutch, summarised, lavishly, maxime, appleby,
# Nearest to states: morbidity, match, pueblo, kingdom, aristocratic, coe, employees, clarinetist,
# Nearest to after: before, when, from, bertie, into, tunisian, became, around,
# Nearest to four: six, eight, five, three, seven, two, nine, zero,
# Nearest to use: nitrite, mystery, seldom, arches, what, tones, tompkins, facing,
# Nearest to world: transformation, bil, precipitates, assimilation, bureaucrats, senna, sponsoring, obstruct,
# Nearest to which: that, who, also, this, it, there, prevailed, primarily,
# Nearest to there: it, they, he, meander, she, which, uttar, now,
# Nearest to state: gabor, dodecanese, inexperience, alabama, satchmo, buber, national, julian,
# Average loss at step 22000: 3.500652
# Average loss at step 24000: 3.489398
# Average loss at step 26000: 3.479226
# Average loss at step 28000: 3.476393
# Average loss at step 30000: 3.498025
# Nearest to so: impressionists, edu, optimates, biotech, hovercraft, cadet, sometimes, sulaiman,
# Nearest to he: she, it, they, who, there, never, pall, which,
# Nearest to may: can, would, could, should, will, cannot, must, might,
# Nearest to years: months, talisman, centuries, times, justice, palliative, year, lbs,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to war: varela, cia, lon, panther, isdn, kib, mira, looting,
# Nearest to can: may, could, must, would, should, will, might, cannot,
# Nearest to american: british, english, dutch, german, maxime, italian, mvp, fenwick,
# Nearest to states: kingdom, pueblo, nations, morbidity, resulted, match, garnier, coe,
# Nearest to after: before, when, during, tunisian, around, into, for, from,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to use: nitrite, cultivated, mystery, unethical, most, bethune, sadism, lanes,
# Nearest to world: bil, transformation, precipitates, restorative, assimilation, sponsoring, wasps, senna,
# Nearest to which: this, that, who, it, also, there, prevailed, what,
# Nearest to there: they, it, he, now, also, often, which, she,
# Nearest to state: gabor, national, strickland, true, satchmo, extravagant, institutions, inexperience,
# Average loss at step 32000: 3.501072
# Average loss at step 34000: 3.493370
# Average loss at step 36000: 3.456385
# Average loss at step 38000: 3.299313
# Average loss at step 40000: 3.429181
# Nearest to so: pronounce, hovercraft, impressionists, debates, optimates, edu, kills, why,
# Nearest to he: she, it, they, there, who, never, i, this,
# Nearest to may: can, will, could, would, should, cannot, must, might,
# Nearest to years: months, centuries, days, times, talisman, lbs, rus, furnish,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to war: cia, panther, varela, lon, looting, nutmeg, workgroups, during,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to american: british, dutch, german, english, russian, italian, australian, harmonize,
# Nearest to states: kingdom, nations, pueblo, lionel, aristocratic, samaritan, state, garnier,
# Nearest to after: before, when, during, penrose, tunisian, landline, organizational, until,
# Nearest to four: six, eight, five, two, seven, three, nine, one,
# Nearest to use: nitrite, sadism, support, cultivated, arches, mystery, envelope, uncommon,
# Nearest to world: transformation, bil, nile, berkley, catamarans, wco, precipitates, serling,
# Nearest to which: that, this, who, also, it, prevailed, mainly, there,
# Nearest to there: they, it, he, she, usually, now, still, unlikely,
# Nearest to state: government, gabor, national, extravagant, inexperience, strickland, states, satchmo,
# Average loss at step 42000: 3.433526
# Average loss at step 44000: 3.457246
# Average loss at step 46000: 3.449496
# Average loss at step 48000: 3.350281
# Average loss at step 50000: 3.381804
# Nearest to so: impressionists, why, kills, baal, trotsky, delete, sometimes, augusta,
# Nearest to he: she, it, they, who, there, never, this, dylan,
# Nearest to may: can, would, could, should, will, cannot, might, must,
# Nearest to years: months, days, centuries, times, decades, talisman, rus, furnish,
# Nearest to nine: seven, eight, six, four, three, five, one, two,
# Nearest to war: cia, whistleblower, during, panther, hex, arab, varela, nutmeg,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to american: dutch, british, english, australian, italian, longwave, irish, redeemed,
# Nearest to states: kingdom, nations, pueblo, lionel, orloff, politics, aristocratic, nicene,
# Nearest to after: before, when, during, penrose, tunisian, until, explains, landline,
# Nearest to four: six, five, three, seven, eight, nine, two, one,
# Nearest to use: bethune, sadism, nitrite, unethical, unarable, support, order, arches,
# Nearest to world: bil, transformation, nile, eng, serling, wco, superpowers, socio,
# Nearest to which: that, this, also, who, what, often, actually, but,
# Nearest to there: they, it, he, she, now, still, these, resolver,
# Nearest to state: gabor, national, inexperience, government, states, extravagant, burned, strickland,
# Average loss at step 52000: 3.435182
# Average loss at step 54000: 3.424472
# Average loss at step 56000: 3.434297
# Average loss at step 58000: 3.394415
# Average loss at step 60000: 3.394590
# Nearest to so: impressionists, delete, kills, trotsky, pronounce, hovercraft, something, sulaiman,
# Nearest to he: she, it, they, who, never, there, schwa, later,
# Nearest to may: can, will, should, would, could, might, must, cannot,
# Nearest to years: months, days, times, centuries, decades, rus, year, minutes,
# Nearest to nine: eight, six, seven, four, five, three, one, two,
# Nearest to war: cia, varela, panther, whistleblower, hex, wars, looting, during,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to american: british, italian, australian, dutch, european, german, english, international,
# Nearest to states: kingdom, nations, countries, politics, lionel, coe, pueblo, orloff,
# Nearest to after: before, during, when, despite, without, penrose, throughout, through,
# Nearest to four: five, eight, six, seven, three, nine, two, one,
# Nearest to use: because, changes, uncommon, most, arches, risk, bethune, promotion,
# Nearest to world: bil, transformation, history, aberdeen, serling, eng, wco, socio,
# Nearest to which: that, this, what, who, it, these, lumberjack, however,
# Nearest to there: it, they, now, she, still, he, we, this,
# Nearest to state: government, value, national, inexperience, states, gabor, encumbered, burned,
# Average loss at step 62000: 3.242216
# Average loss at step 64000: 3.253459
# Average loss at step 66000: 3.407777
# Average loss at step 68000: 3.396709
# Average loss at step 70000: 3.354918
# Nearest to so: impressionists, davies, strengthen, hideous, sulaiman, beyond, monomorphism, hovercraft,
# Nearest to he: she, it, they, never, there, schwa, who, we,
# Nearest to may: can, will, would, could, should, might, must, cannot,
# Nearest to years: months, days, decades, centuries, times, year, rus, weeks,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to war: cia, whistleblower, wars, panther, nutmeg, varela, arab, hex,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Nearest to american: british, italian, dutch, european, german, african, english, harmonize,
# Nearest to states: kingdom, nations, countries, state, resulted, pueblo, lionel, employees,
# Nearest to after: before, during, when, penrose, despite, without, while, through,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to use: changes, treatment, most, because, accept, unarable, patriarchs, orbited,
# Nearest to world: bil, transformation, gulf, noblemen, catamarans, gospels, aberdeen, eng,
# Nearest to which: that, this, also, usually, typically, what, these, however,
# Nearest to there: it, they, now, still, she, we, he, often,
# Nearest to state: government, states, council, city, export, inexperience, national, guerrero,
# Average loss at step 72000: 3.368341
# Average loss at step 74000: 3.348180
# Average loss at step 76000: 3.320150
# Average loss at step 78000: 3.352036
# Average loss at step 80000: 3.376101
# Nearest to so: kills, davies, too, monomorphism, baal, hovercraft, something, insufficiently,
# Nearest to he: she, it, they, there, never, who, schwa, soon,
# Nearest to may: can, could, should, will, would, might, must, cannot,
# Nearest to years: months, days, decades, centuries, weeks, times, minutes, year,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to war: cia, whistleblower, wars, nutmeg, arab, panther, barracks, varela,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to american: british, italian, german, dutch, australian, canadian, french, irish,
# Nearest to states: kingdom, nations, countries, resulted, state, employees, trajan, politics,
# Nearest to after: before, during, when, without, despite, penrose, while, though,
# Nearest to four: five, six, seven, eight, three, nine, two, one,
# Nearest to use: risk, treatment, because, orbited, support, patriarchs, unarable, list,
# Nearest to world: bil, gulf, eng, transformation, catamarans, wco, aberdeen, tower,
# Nearest to which: that, this, usually, what, also, typically, mainly, prevailed,
# Nearest to there: it, they, he, she, still, we, now, usually,
# Nearest to state: city, government, states, council, inexperience, guerrero, trajan, bonner,
# Average loss at step 82000: 3.411887
# Average loss at step 84000: 3.408531
# Average loss at step 86000: 3.387929
# Average loss at step 88000: 3.351060
# Average loss at step 90000: 3.363557
# Nearest to so: too, kills, monomorphism, beyond, lofty, something, sasaki, baal,
# Nearest to he: she, it, they, there, never, who, later, soon,
# Nearest to may: can, could, should, might, would, will, must, cannot,
# Nearest to years: days, months, decades, centuries, minutes, weeks, year, times,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to war: cia, wars, whistleblower, during, icrc, nutmeg, barracks, panther,
# Nearest to can: could, may, would, will, should, might, cannot, must,
# Nearest to american: british, italian, australian, dutch, canadian, german, irish, french,
# Nearest to states: kingdom, nations, countries, resulted, us, state, politics, employees,
# Nearest to after: before, during, when, despite, without, while, until, penrose,
# Nearest to four: seven, five, eight, six, three, two, nine, one,
# Nearest to use: risk, treatment, orbited, support, because, complement, spiders, patriarchs,
# Nearest to world: bil, transformation, gulf, aberdeen, eng, entheogen, sudan, sulawesi,
# Nearest to which: that, this, also, usually, what, who, actually, prevailed,
# Nearest to there: they, it, she, he, now, still, we, sometimes,
# Nearest to state: city, government, states, council, national, kashima, value, alluding,
# Average loss at step 92000: 3.396579
# Average loss at step 94000: 3.253270
# Average loss at step 96000: 3.355912
# Average loss at step 98000: 3.240515
# Average loss at step 100000: 3.353592
# Nearest to so: too, thus, then, sasaki, adlai, when, kills, something,
# Nearest to he: she, it, they, there, never, we, who, gradually,
# Nearest to may: can, could, might, should, will, must, would, cannot,
# Nearest to years: days, months, decades, centuries, minutes, weeks, year, times,
# Nearest to nine: eight, seven, six, five, four, three, two, zero,
# Nearest to war: cia, wars, whistleblower, panther, varela, kib, barracks, streaming,
# Nearest to can: could, may, will, would, must, cannot, might, should,
# Nearest to american: british, canadian, italian, australian, french, german, bandleaders, irish,
# Nearest to states: kingdom, nations, countries, state, resulted, employees, us, airlines,
# Nearest to after: before, during, when, without, penrose, despite, until, while,
# Nearest to four: seven, six, five, eight, two, nine, three, zero,
# Nearest to use: complement, treatment, changes, risk, support, spiders, orbited, bethune,
# Nearest to world: bil, gulf, ashes, sulawesi, aberdeen, delegate, berkley, transformation,
# Nearest to which: that, this, actually, usually, these, typically, what, still,
# Nearest to there: they, it, he, she, now, still, sometimes, we,
# Nearest to state: city, states, government, trajan, national, leninism, kashima, council,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
tf.truncated_normal?
