# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('Sample data words')
for i in data[:10]:
    print('\t{}'.format(reverse_dictionary[i]))
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3083, 12, 6, 195, 2, 3137, 46, 59, 156]
# Sample data words
# 	anarchism
# 	originated
# 	as
# 	a
# 	term
# 	of
# 	abuse
# 	first
# 	used
# 	against

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    #print('buffer:',buffer)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

#print('data:', [reverse_dictionary[di] for di in data[:8]])


batch, labels = generate_batch(batch_size=8, num_skips=4, skip_window=2)
print(batch)
print(labels)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# [12 12 12 12  6  6  6  6]
# [[3083]
#  [   6]
#  [5243]
#  [ 195]
#  [  12]
#  [3083]
#  [   2]
#  [ 195]]
# 12 as -> 3083 originated
# 12 as -> 6 a
# 12 as -> 5243 anarchism
# 12 as -> 195 term
# 6 a -> 12 as
# 6 a -> 3083 originated
# 6 a -> 2 of
# 6 a -> 195 term
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
tf.nn.embedding_lookup?

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  #tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.449435
# Nearest to use: macintoshes, brownish, belt, algebra, britanniae, outlaws, broadened, monic,
# Nearest to two: introduction, redaction, mistrust, escher, screenwriters, headset, yorkshire, daemen,
# Nearest to a: cans, prokaryotes, accumulates, hrothgar, synge, lufthansa, healed, gourd,
# Nearest to would: sns, alastair, motion, thread, vilified, schenectady, destroys, instantly,
# Nearest to three: yelling, spousal, gallurese, toltec, fluids, gush, mackaye, mays,
# Nearest to their: sunspot, game, stiller, overloaded, mews, orbited, kernow, budding,
# Nearest to had: satyagraha, mozart, scribes, storyteller, tip, saxon, ize, fulda,
# Nearest to world: joke, gwen, rejoicing, praising, rumba, hypomania, intramolecular, bribes,
# Nearest to more: aon, les, rito, paleontological, oracle, wrest, kalevala, revenge,
# Nearest to with: expo, eq, vilas, alexius, reinforcements, entropy, boeotia, hak,
# Nearest to so: bermuda, incarnation, songwriting, volcanoes, indexed, ney, jarrett, bases,
# Nearest to new: executors, dfts, babylonia, kwame, skaro, kessler, evolved, crashed,
# Nearest to also: mayday, filament, agreeing, accademia, excommunicated, letsie, leitrim, ballad,
# Nearest to but: integral, penalty, compare, webs, guru, phonemes, treatment, runge,
# Nearest to the: gai, hailed, exceeded, basileus, nanda, sherman, mactutor, christus,
# Nearest to no: eldest, hominidae, hale, chipping, equally, indic, asians, leanings,
# Average loss at step 2000: 4.351689
# Average loss at step 4000: 3.869857
# Average loss at step 6000: 3.786624
# Average loss at step 8000: 3.677771
# Average loss at step 10000: 3.609123
# Nearest to use: plainly, plundering, outlaws, djbdns, macintoshes, brownish, rostock, parishioners,
# Nearest to two: four, five, three, six, seven, eight, zero, nine,
# Nearest to a: the, heraldic, castello, harmattan, electrolyte, yvonne, no, reims,
# Nearest to would: can, may, might, will, melts, could, to, thread,
# Nearest to three: four, six, five, eight, seven, two, zero, nine,
# Nearest to their: his, the, its, this, ostracism, kernow, repose, midst,
# Nearest to had: has, have, was, been, were, satyagraha, leads, tip,
# Nearest to world: rejoicing, broccoli, sys, joke, eldr, expound, bribes, praising,
# Nearest to more: kalevala, infusions, astrolabe, aon, languedoc, unaids, further, oracle,
# Nearest to with: into, for, expo, in, online, by, retaliate, reinforcements,
# Nearest to so: karo, inlets, indexed, blythe, amitabh, kramer, incarnation, guru,
# Nearest to new: kwame, crashed, khayy, dfts, sesotho, evolved, defector, renowned,
# Nearest to also: which, charismatic, it, stems, often, fife, deviation, waco,
# Nearest to but: besieging, extraordinary, is, and, persecute, are, penalty, still,
# Nearest to the: a, this, his, its, their, pds, an, exorcist,
# Nearest to no: barclay, shandy, chipping, equally, indic, acuity, gladio, it,
# Average loss at step 12000: 3.607398
# Average loss at step 14000: 3.570051
# Average loss at step 16000: 3.410604
# Average loss at step 18000: 3.457136
# Average loss at step 20000: 3.537903
# Nearest to use: plundering, all, plainly, tones, marek, djbdns, hotspur, parishioners,
# Nearest to two: three, five, four, eight, six, seven, one, nine,
# Nearest to a: no, this, the, racers, privations, abner, any, initially,
# Nearest to would: can, may, could, will, might, should, to, did,
# Nearest to three: four, two, five, seven, eight, six, nine, zero,
# Nearest to their: his, its, the, splines, lyotropic, her, any, postage,
# Nearest to had: has, have, were, was, been, posteriori, hoe, figurative,
# Nearest to world: rejoicing, sys, broccoli, joke, bribes, expound, praising, country,
# Nearest to more: less, kalevala, most, astrolabe, unaids, languedoc, gilmore, further,
# Nearest to with: into, in, for, expo, between, hennecke, retaliate, by,
# Nearest to so: sergeant, karo, kramer, szczecin, hostility, indexed, kn, werewolf,
# Nearest to new: kwame, building, crashed, lances, fluctuated, khayy, evolved, dfts,
# Nearest to also: often, which, usually, now, never, not, therefore, hatta,
# Nearest to but: however, and, besieging, which, that, although, extraordinary, is,
# Nearest to the: their, its, this, his, a, foulke, each, an,
# Nearest to no: a, barclay, equally, chipping, shandy, gladio, indic, kirlian,
# Average loss at step 22000: 3.507983
# Average loss at step 24000: 3.492387
# Average loss at step 26000: 3.480942
# Average loss at step 28000: 3.479541
# Average loss at step 30000: 3.499365
# Nearest to use: all, plundering, marek, djbdns, preferring, most, plainly, mundar,
# Nearest to two: four, one, three, five, six, seven, eight, nine,
# Nearest to a: the, no, yvonne, his, any, filioque, ethicists, elizabethan,
# Nearest to would: can, will, may, could, might, should, must, did,
# Nearest to three: four, five, seven, eight, six, two, nine, zero,
# Nearest to their: its, his, the, her, any, lyotropic, these, some,
# Nearest to had: has, have, was, were, having, platelets, been, is,
# Nearest to world: rejoicing, country, broccoli, undefended, auschwitz, sys, puppet, varphi,
# Nearest to more: less, most, larger, rather, kalevala, fertile, astrolabe, very,
# Nearest to with: between, into, expo, in, hennecke, nicene, for, allgemeine,
# Nearest to so: sergeant, szczecin, kramer, unauthorized, karo, newtons, reluctance, workgroups,
# Nearest to new: kwame, khayy, viennese, great, ferocious, grammars, fluctuated, dfts,
# Nearest to also: often, now, it, which, usually, frequently, never, sometimes,
# Nearest to but: however, although, and, though, that, which, when, or,
# Nearest to the: their, its, his, a, aida, some, our, many,
# Nearest to no: a, barclay, gladio, chipping, mould, equally, little, acuity,
# Average loss at step 32000: 3.501987
# Average loss at step 34000: 3.492303
# Average loss at step 36000: 3.452382
# Average loss at step 38000: 3.304927
# Average loss at step 40000: 3.430558
# Nearest to use: plundering, programmatic, nordic, invert, tones, mundar, most, djbdns,
# Nearest to two: three, four, six, five, seven, one, nine, eight,
# Nearest to a: the, no, another, or, any, every, barometer, yvonne,
# Nearest to would: will, can, could, may, might, should, must, did,
# Nearest to three: seven, four, five, six, two, nine, eight, one,
# Nearest to their: its, his, her, any, the, some, lyotropic, several,
# Nearest to had: has, have, was, were, began, been, having, montt,
# Nearest to world: rejoicing, undefended, stromata, sys, definitive, evagrius, broccoli, country,
# Nearest to more: less, most, larger, rather, very, fertile, astrolabe, greater,
# Nearest to with: between, into, while, for, aground, screws, murnau, polar,
# Nearest to so: sergeant, hairs, szczecin, kramer, jarrett, argues, deo, bluegrass,
# Nearest to new: kwame, fluctuated, khayy, standard, ferocious, tiers, building, pineapples,
# Nearest to also: often, which, now, usually, generally, there, then, caterpillars,
# Nearest to but: however, and, although, while, duluth, it, though, besieging,
# Nearest to the: a, this, each, any, their, its, leipzig, his,
# Nearest to no: a, any, equally, gladio, little, cooperates, acuity, barclay,
# Average loss at step 42000: 3.434281
# Average loss at step 44000: 3.453770
# Average loss at step 46000: 3.451777
# Average loss at step 48000: 3.351268
# Average loss at step 50000: 3.383428
# Nearest to use: range, plundering, nordic, creation, programmatic, end, mundar, synonyms,
# Nearest to two: three, six, four, eight, one, five, seven, zero,
# Nearest to a: the, racers, yvonne, beckett, another, kaifu, reims, any,
# Nearest to would: will, could, may, can, might, should, must, did,
# Nearest to three: four, six, eight, seven, five, nine, two, zero,
# Nearest to their: its, his, her, the, your, several, some, many,
# Nearest to had: has, have, was, having, were, been, began, did,
# Nearest to world: stromata, rejoicing, combs, largest, nutrition, undefended, definitive, stunts,
# Nearest to more: less, most, very, larger, rather, faster, astrolabe, fertile,
# Nearest to with: between, betray, into, allgemeine, dispositions, cheng, loader, nnn,
# Nearest to so: bluegrass, kramer, deo, if, then, sergeant, hairs, szczecin,
# Nearest to new: great, kwame, khayy, tiers, standard, freeview, ferocious, aai,
# Nearest to also: often, which, then, now, who, frequently, generally, workload,
# Nearest to but: however, although, while, though, duluth, and, when, that,
# Nearest to the: its, their, his, this, a, shu, bluntly, lighters,
# Nearest to no: any, little, equally, iy, gladio, cooperates, twist, kirlian,
# Average loss at step 52000: 3.439118
# Average loss at step 54000: 3.427713
# Average loss at step 56000: 3.435073
# Average loss at step 58000: 3.392940
# Average loss at step 60000: 3.391144
# Nearest to use: range, plundering, commentarii, most, creation, because, invert, professionals,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to a: the, any, no, another, racers, this, restraints, yvonne,
# Nearest to would: could, will, may, can, might, should, must, cannot,
# Nearest to three: four, five, six, eight, two, seven, nine, one,
# Nearest to their: its, his, her, your, the, some, our, whose,
# Nearest to had: has, have, was, having, were, did, began, tried,
# Nearest to world: country, undefended, rejoicing, church, nutrition, heracleidae, supercharger, largest,
# Nearest to more: less, most, larger, rather, very, greater, longer, other,
# Nearest to with: between, by, into, grande, in, while, expo, nnn,
# Nearest to so: if, then, aluminum, hairs, cctld, koch, unrealistic, instructions,
# Nearest to new: kwame, utilizes, tiers, pineapples, grammars, aai, sesotho, ferocious,
# Nearest to also: often, now, generally, then, frequently, usually, workload, sometimes,
# Nearest to but: however, although, and, duluth, quixote, see, while, though,
# Nearest to the: its, a, their, any, his, this, nls, beefheart,
# Nearest to no: any, little, a, outperform, francia, rancho, disproven, equaled,
# Average loss at step 62000: 3.235573
# Average loss at step 64000: 3.259427
# Average loss at step 66000: 3.403236
# Average loss at step 68000: 3.392531
# Average loss at step 70000: 3.358689
# Nearest to use: commentarii, range, most, synonyms, because, support, creation, invert,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to a: the, another, any, racers, profanity, yvonne, privations, reims,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to their: its, his, her, the, your, some, our, these,
# Nearest to had: has, have, was, were, having, been, platelets, began,
# Nearest to world: country, largest, nutrition, undefended, recreating, pesky, church, dream,
# Nearest to more: less, most, very, rather, larger, too, faster, extremely,
# Nearest to with: between, into, betray, grande, screws, anthropic, causing, expo,
# Nearest to so: if, sos, hairs, then, sometimes, deo, instructions, aluminum,
# Nearest to new: kwame, utilizes, pineapples, amritsar, tiers, assembl, fluctuated, exhausts,
# Nearest to also: often, now, which, still, sometimes, usually, generally, then,
# Nearest to but: however, although, which, that, though, and, still, while,
# Nearest to the: their, its, a, this, any, these, each, some,
# Nearest to no: little, any, rancho, fruitarians, there, cooperates, mrnas, disproven,
# Average loss at step 72000: 3.369315
# Average loss at step 74000: 3.346464
# Average loss at step 76000: 3.313638
# Average loss at step 78000: 3.349378
# Average loss at step 80000: 3.379445
# Nearest to use: because, range, commentarii, support, synonyms, appian, way, obi,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to a: the, another, yvonne, privations, kaifu, castello, prosthetics, every,
# Nearest to would: could, will, may, might, can, must, should, cannot,
# Nearest to three: four, six, seven, five, eight, two, nine, zero,
# Nearest to their: its, his, her, your, our, my, any, the,
# Nearest to had: has, have, was, were, having, began, mordred, platelets,
# Nearest to world: country, recreating, intuitionistic, pesky, shuts, nutrition, fayed, session,
# Nearest to more: less, most, very, rather, larger, extremely, too, faster,
# Nearest to with: between, into, in, tagus, dispositions, uua, by, elder,
# Nearest to so: if, sos, then, hairs, aluminum, merchandising, unrealistic, manifest,
# Nearest to new: kwame, defining, tiers, utilizes, astronomically, fluctuated, assembl, cheer,
# Nearest to also: now, often, still, sometimes, which, generally, actually, usually,
# Nearest to but: however, although, though, and, while, which, that, than,
# Nearest to the: a, this, pleasuredome, fugal, their, its, celia, jugnauth,
# Nearest to no: little, any, rancho, fruitarians, technicians, mrnas, iy, doctorate,
# Average loss at step 82000: 3.407524
# Average loss at step 84000: 3.406566
# Average loss at step 86000: 3.386845
# Average loss at step 88000: 3.353665
# Average loss at step 90000: 3.366089
# Nearest to use: support, because, synonyms, appian, range, practice, plundering, actuality,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Nearest to a: yvonne, another, the, any, every, thermally, beckett, awake,
# Nearest to would: could, will, might, may, can, must, should, cannot,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to had: has, have, was, were, having, posteriori, platelets, mordred,
# Nearest to world: country, session, nde, repeatable, heracleidae, undefended, clp, pergamum,
# Nearest to more: less, very, most, rather, faster, increasingly, too, greater,
# Nearest to with: between, in, by, into, nnn, pra, against, guarneri,
# Nearest to so: if, hairs, sos, then, yusuf, thus, aluminum, incarnation,
# Nearest to new: utilizes, defining, viennese, assembl, cheer, different, kwame, great,
# Nearest to also: often, still, now, which, sometimes, generally, actually, usually,
# Nearest to but: however, and, although, while, though, which, until, jonny,
# Nearest to the: its, this, shu, their, any, a, his, fugal,
# Nearest to no: any, little, only, technicians, exclusive, cooperates, fruitarians, than,
# Average loss at step 92000: 3.402574
# Average loss at step 94000: 3.254139
# Average loss at step 96000: 3.354932
# Average loss at step 98000: 3.240468
# Average loss at step 100000: 3.354143
# Nearest to use: support, range, way, synonyms, commentarii, because, most, practice,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to a: racers, another, any, privations, the, hostels, richey, golfers,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to three: five, four, seven, two, six, eight, nine, zero,
# Nearest to their: its, his, her, your, our, the, my, splines,
# Nearest to had: has, have, having, were, was, would, mordred, wanted,
# Nearest to world: country, session, shuts, season, clp, intuitionistic, undefended, allocations,
# Nearest to more: less, most, very, rather, larger, faster, extremely, greater,
# Nearest to with: between, betray, in, into, dispositions, causing, expo, including,
# Nearest to so: hairs, if, then, sos, aluminum, thus, later, secondo,
# Nearest to new: kwame, defining, different, utilizes, equestrian, academic, tiers, sesotho,
# Nearest to also: now, still, often, actually, sometimes, generally, who, usually,
# Nearest to but: however, although, though, and, while, duluth, which, additionally,
# Nearest to the: his, their, your, its, our, each, this, obelisk,
# Nearest to no: any, little, only, mrnas, cooperates, technicians, rancho, another,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
tf.truncated_normal?

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    #print('buffer:',buffer)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

#print('data:', [reverse_dictionary[di] for di in data[:8]])


batch, labels = generate_batch(batch_size=8, num_skips=4, skip_window=2)
print(batch)
print(labels)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# [5243 3083  195    6   12    2 3083  195]
# [[12]
#  [12]
#  [12]
#  [12]
#  [ 6]
#  [ 6]
#  [ 6]
#  [ 6]]
# 5243 anarchism -> 12 as
# 3083 originated -> 12 as
# 195 term -> 12 as
# 6 a -> 12 as
# 12 as -> 6 a
# 2 of -> 6 a
# 3083 originated -> 6 a
# 195 term -> 6 a
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'originated', 'anarchism', 'term', 'of', 'as', 'term', 'originated']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  #tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.846020
# Nearest to the: hunchback, ears, electrician, mustafa, keynes, presidential, parts, scripted,
# Nearest to a: madero, migration, suing, almagro, renovation, nests, jiva, sensual,
# Nearest to d: combinatory, actionscript, transition, resin, belloc, rhetoric, adversaries, galil,
# Nearest to zero: feces, ets, harvester, possessing, maleficarum, sunken, wedgwood, unesco,
# Nearest to from: premierships, tight, steppes, lydia, incapacitation, steal, bridging, confluence,
# Nearest to people: herrings, sephardim, intestinal, ioannis, proceeded, patterning, saimei, postmodernism,
# Nearest to there: packages, laird, convoys, lk, alternative, improving, deconstruction, boudinot,
# Nearest to states: jealousy, spee, supply, ferrara, raps, sales, lustre, lymphoid,
# Nearest to see: hydrazine, tee, iq, bassline, insurer, english, karnataka, leanings,
# Nearest to united: booklet, sca, hilton, singularities, opteron, law, backstory, lisa,
# Nearest to may: mico, buns, darwin, capability, namur, nantes, jeong, lbf,
# Nearest to b: gears, vermeer, minimise, prize, pronouncements, query, injection, pluperfect,
# Nearest to th: refraction, metronome, coworkers, rocketry, system, barred, layers, mulcahy,
# Nearest to on: victims, reliance, conquers, monitored, angelic, brave, packs, spiritually,
# Nearest to have: ascends, screwtape, fortran, roll, cure, circumcision, flavoring, underdog,
# Nearest to with: ruler, iliad, oversees, stafford, castor, calatrava, anarchism, copper,
# Average loss at step 2000: 4.361161
# Average loss at step 4000: 3.869408
# Average loss at step 6000: 3.789232
# Average loss at step 8000: 3.688638
# Average loss at step 10000: 3.614137
# Nearest to the: his, a, its, this, their, crusade, sidonia, an,
# Nearest to a: the, vomiting, triumvirate, flurry, limburgish, herbal, neale, leyland,
# Nearest to d: and, allgemeine, galil, combinatory, adriaan, b, takeshi, tollens,
# Nearest to zero: nine, eight, five, six, seven, three, four, two,
# Nearest to from: in, between, nir, with, adhesion, into, booch, fermilab,
# Nearest to people: herrings, baltic, vicente, estrada, writeups, patterning, fung, ioannis,
# Nearest to there: it, he, they, which, not, packages, greve, mutant,
# Nearest to states: supply, jealousy, raps, masoretic, conspiracy, spee, ferrara, sales,
# Nearest to see: bump, iq, constructivists, english, karnataka, netsplit, antique, pleiades,
# Nearest to united: law, singularities, flavorings, opteron, summaries, steps, aching, sca,
# Nearest to may: would, can, aai, mico, could, darwin, will, midas,
# Nearest to b: dingo, pronouncements, palestinians, roaring, tries, d, gears, pluperfect,
# Nearest to th: four, seven, metres, rocketry, coworkers, layers, metronome, fortified,
# Nearest to on: in, conquers, about, reliance, under, spiritually, upon, imprints,
# Nearest to have: be, had, has, were, are, do, garbage, bribed,
# Nearest to with: cin, in, iliad, for, fluoride, from, percentile, under,
# Average loss at step 12000: 3.604710
# Average loss at step 14000: 3.574385
# Average loss at step 16000: 3.408666
# Average loss at step 18000: 3.458475
# Average loss at step 20000: 3.543485
# Nearest to the: its, their, this, runes, his, mychal, many, any,
# Nearest to a: this, any, no, jiva, aphelion, the, nicotine, deregulation,
# Nearest to d: b, takeshi, inquisition, yap, galil, and, shawnee, bows,
# Nearest to zero: six, five, eight, seven, nine, four, three, two,
# Nearest to from: between, into, at, in, under, by, and, after,
# Nearest to people: years, fung, estrada, mosaic, instants, writeups, leukocytes, rushed,
# Nearest to there: they, it, he, however, which, who, midwifery, now,
# Nearest to states: supply, jealousy, conspiracy, raps, spee, razzie, noumenon, masoretic,
# Nearest to see: clc, bump, pleiades, constructivists, agni, pryor, antique, nilotic,
# Nearest to united: law, summaries, flavorings, singularities, steps, opteron, sca, kat,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to b: d, dingo, palestinians, yap, folie, disappearances, pp, pronouncements,
# Nearest to th: metres, eight, layers, fortified, koalas, coworkers, seven, hulk,
# Nearest to on: in, upon, conquers, spiritually, at, reliance, kat, protestant,
# Nearest to have: had, has, were, be, are, by, appear, screwtape,
# Nearest to with: between, in, for, by, liberian, lower, confining, cin,
# Average loss at step 22000: 3.500925
# Average loss at step 24000: 3.487063
# Average loss at step 26000: 3.481041
# Average loss at step 28000: 3.480008
# Average loss at step 30000: 3.498563
# Nearest to the: its, their, fd, his, runes, a, eridanus, abandonment,
# Nearest to a: any, preoccupied, the, disputation, dvb, no, nicotine, his,
# Nearest to d: b, inquisition, aspiration, takeshi, galil, yap, nat, careers,
# Nearest to zero: seven, eight, five, nine, four, six, three, two,
# Nearest to from: into, under, between, in, on, after, of, steppes,
# Nearest to people: rushed, years, instants, fung, nationalism, mehmed, mosaic, lighthouses,
# Nearest to there: they, it, he, however, still, now, who, poisonous,
# Nearest to states: conspiracy, state, supply, countries, lackey, jealousy, razzie, raps,
# Nearest to see: clc, nilotic, integrating, include, bump, constructivists, pleiades, fgc,
# Nearest to united: law, flavorings, atonal, theorie, summaries, singularities, devising, synge,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Nearest to b: d, dingo, yap, folie, pronouncements, gratis, adriaan, disappearances,
# Nearest to th: six, seven, eight, nine, metres, rd, koalas, zero,
# Nearest to on: in, upon, under, at, from, for, spiritually, about,
# Nearest to have: had, has, were, are, be, get, include, appear,
# Nearest to with: between, unwilling, liberian, peabody, cin, for, landmarks, evolutionists,
# Average loss at step 32000: 3.504023
# Average loss at step 34000: 3.490525
# Average loss at step 36000: 3.452306
# Average loss at step 38000: 3.296989
# Average loss at step 40000: 3.426191
# Nearest to the: their, his, this, a, its, each, any, another,
# Nearest to a: the, another, any, or, jiva, pivots, serials, branden,
# Nearest to d: b, inquisition, UNK, nat, aspiration, contemplated, yap, ecoregions,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to from: into, between, through, in, fermilab, capillaries, of, after,
# Nearest to people: instants, individuals, others, mosaic, terrorism, writeups, lighthouses, rushed,
# Nearest to there: they, it, he, still, now, who, also, which,
# Nearest to states: state, countries, kingdom, conspiracy, nations, noumenon, iers, companies,
# Nearest to see: bump, clc, include, integrating, constructivists, paddy, suspect, fgc,
# Nearest to united: devising, law, flavorings, caribbean, theorie, singularities, joined, atonal,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to b: d, pronouncements, c, yap, pp, dingo, eclipsing, steele,
# Nearest to th: seven, eight, metres, rd, twentieth, nlm, coworkers, feet,
# Nearest to on: upon, in, reliance, at, diablo, during, imprints, loosely,
# Nearest to have: had, has, were, are, be, include, homotopy, get,
# Nearest to with: when, between, by, cin, fluoride, from, ignorance, in,
# Average loss at step 42000: 3.438225
# Average loss at step 44000: 3.453203
# Average loss at step 46000: 3.448845
# Average loss at step 48000: 3.350497
# Average loss at step 50000: 3.381297
# Nearest to the: their, its, this, a, any, his, an, coexisted,
# Nearest to a: the, any, another, vomiting, gwynne, subtree, nicotine, no,
# Nearest to d: b, m, inquisition, haze, dressed, mathbf, n, c,
# Nearest to zero: eight, nine, five, seven, six, four, three, two,
# Nearest to from: into, in, across, between, after, through, under, during,
# Nearest to people: years, ptc, steno, scholars, instants, mosaic, children, lighthouses,
# Nearest to there: they, it, he, now, still, who, which, poisonous,
# Nearest to states: kingdom, countries, state, nations, sufism, conspiracy, microkernel, lackey,
# Nearest to see: integrating, clc, bump, include, nilotic, democritus, paddy, disappearances,
# Nearest to united: devising, atonal, kat, law, constitution, summaries, joined, clutch,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to b: d, c, pronouncements, x, yap, eclipsing, r, pp,
# Nearest to th: eight, twentieth, four, metres, rd, bc, ad, seven,
# Nearest to on: upon, in, reliance, loosely, through, jaber, gahan, within,
# Nearest to have: had, were, has, be, are, ever, amiens, hofmann,
# Nearest to with: between, cin, by, in, confining, disguising, percentile, elaborates,
# Average loss at step 52000: 3.437109
# Average loss at step 54000: 3.423642
# Average loss at step 56000: 3.439767
# Average loss at step 58000: 3.395334
# Average loss at step 60000: 3.392830
# Nearest to the: its, their, a, his, this, any, lune, isambard,
# Nearest to a: another, the, any, nicotine, jiva, dvb, secede, sle,
# Nearest to d: b, c, m, mathbf, q, aspiration, n, haze,
# Nearest to zero: four, five, seven, eight, six, nine, three, two,
# Nearest to from: into, after, between, through, capillaries, compact, billing, including,
# Nearest to people: others, instants, scholars, fans, children, ptc, represented, steno,
# Nearest to there: they, it, often, now, he, this, still, she,
# Nearest to states: kingdom, countries, nations, state, admit, otimes, noumenon, bodkin,
# Nearest to see: include, dara, clc, fgc, democritus, integrating, links, list,
# Nearest to united: devising, constitution, joined, atonal, flavorings, kat, summaries, law,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to b: d, c, r, x, pronouncements, m, f, n,
# Nearest to th: seven, eight, twentieth, six, four, five, bc, ad,
# Nearest to on: upon, in, through, within, gahan, aquino, about, kroto,
# Nearest to have: had, has, were, are, be, include, get, hofmann,
# Nearest to with: between, cin, in, by, when, initiation, megali, jocular,
# Average loss at step 62000: 3.240245
# Average loss at step 64000: 3.256474
# Average loss at step 66000: 3.405852
# Average loss at step 68000: 3.395284
# Average loss at step 70000: 3.352483
# Nearest to the: their, its, some, this, a, any, these, his,
# Nearest to a: another, the, jiva, enough, aphelion, branden, any, its,
# Nearest to d: b, n, mathbf, h, m, r, ar, g,
# Nearest to zero: eight, five, six, four, seven, nine, three, two,
# Nearest to from: into, between, through, across, in, after, byng, positivism,
# Nearest to people: children, scholars, instants, others, men, rushed, fans, ptc,
# Nearest to there: they, it, often, he, now, still, usually, generally,
# Nearest to states: kingdom, nations, state, countries, governments, beatrix, recognition, us,
# Nearest to see: include, list, horizons, fgc, references, cracker, but, clc,
# Nearest to united: devising, joined, atonal, flavorings, singularities, constitution, prepositional, waltrip,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to b: d, r, pronouncements, z, c, n, f, j,
# Nearest to th: twentieth, bc, six, bce, seven, metres, ad, rd,
# Nearest to on: upon, through, in, within, aquino, gahan, jaber, idi,
# Nearest to have: had, has, were, are, be, include, sputtering, develop,
# Nearest to with: between, by, peabody, iliad, dubnium, in, fluoride, into,
# Average loss at step 72000: 3.373012
# Average loss at step 74000: 3.346493
# Average loss at step 76000: 3.309161
# Average loss at step 78000: 3.349491
# Average loss at step 80000: 3.382175
# Nearest to the: their, this, a, his, its, every, lean, each,
# Nearest to a: another, the, every, jiva, any, reacting, leaderships, wikimedia,
# Nearest to d: b, m, g, h, p, c, f, n,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to from: into, through, after, between, across, before, within, during,
# Nearest to people: children, men, others, scholars, fans, students, instants, steno,
# Nearest to there: they, it, he, she, still, often, now, usually,
# Nearest to states: kingdom, countries, nations, state, beatrix, microkernel, us, ordinations,
# Nearest to see: include, disappearances, refer, references, clc, fgc, links, updike,
# Nearest to united: devising, singularities, joined, kat, gum, contradictory, atonal, theorie,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to b: d, c, pronouncements, r, f, z, jutsu, frightened,
# Nearest to th: twentieth, bc, bce, rd, seven, ad, nd, metres,
# Nearest to on: upon, in, through, at, within, swedenborg, metabolite, prospectors,
# Nearest to have: had, has, be, are, include, were, develop, sputtering,
# Nearest to with: between, cin, iliad, dubnium, among, peabody, percentile, intercepts,
# Average loss at step 82000: 3.409154
# Average loss at step 84000: 3.406260
# Average loss at step 86000: 3.385879
# Average loss at step 88000: 3.353569
# Average loss at step 90000: 3.361913
# Nearest to the: its, this, his, their, any, a, giulia, eugenic,
# Nearest to a: another, the, jiva, any, tojo, woolf, every, powerless,
# Nearest to d: b, m, astronaut, c, philanthropist, mathbf, r, catalyzes,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to from: through, into, during, across, between, after, under, within,
# Nearest to people: children, students, men, person, fans, members, others, instants,
# Nearest to there: they, it, he, she, still, we, now, generally,
# Nearest to states: kingdom, countries, state, nations, us, ordinations, rzburg, airlines,
# Nearest to see: references, links, include, list, refer, disappearances, seasoned, intellect,
# Nearest to united: devising, kat, joined, gum, contradictory, atonal, caribbean, constitution,
# Nearest to may: can, could, would, might, should, must, will, cannot,
# Nearest to b: c, d, pronouncements, r, f, z, n, g,
# Nearest to th: twentieth, bce, bc, rd, eight, six, one, nd,
# Nearest to on: upon, under, at, through, vintage, against, idi, windowing,
# Nearest to have: has, had, were, be, are, develop, include, having,
# Nearest to with: between, cin, by, concerning, dubnium, in, including, percentile,
# Average loss at step 92000: 3.396504
# Average loss at step 94000: 3.250827
# Average loss at step 96000: 3.357664
# Average loss at step 98000: 3.241163
# Average loss at step 100000: 3.356920
# Nearest to the: their, its, his, her, clashed, your, this, a,
# Nearest to a: another, any, the, jiva, enough, woolf, relying, dams,
# Nearest to d: b, c, oscar, paul, q, riser, academie, adenauer,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to from: into, through, in, within, positivism, between, across, during,
# Nearest to people: children, men, fans, students, women, others, individuals, person,
# Nearest to there: they, he, it, now, still, she, sometimes, often,
# Nearest to states: kingdom, countries, nations, us, state, airlines, ordinations, pyrimidine,
# Nearest to see: links, references, refer, include, list, lehmann, fgc, external,
# Nearest to united: devising, kat, joined, caribbean, contradictory, gum, aquila, singularities,
# Nearest to may: can, could, should, would, might, will, must, cannot,
# Nearest to b: d, pronouncements, dingo, yap, galil, c, folie, jutsu,
# Nearest to th: twentieth, bc, rd, bce, nd, metres, six, ab,
# Nearest to on: upon, in, through, at, aquino, against, prospectors, wikimedia,
# Nearest to have: had, has, are, develop, were, include, be, indicate,
# Nearest to with: between, cin, peabody, including, wink, using, cohorts, at,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
final_embeddings
# Out:
# array([[-0.15919471,  0.05816918,  0.03517234, ..., -0.05862839,
#         -0.11099485, -0.04895351],
#        [ 0.06336717,  0.10889706, -0.1015365 , ..., -0.1369696 ,
#         -0.02384413,  0.08945072],
#        [-0.02267836, -0.10928107,  0.09629361, ..., -0.05839406,
#         -0.02793482, -0.03148355],
#        ...,
#        [-0.12913632, -0.05794647,  0.10469914, ..., -0.07453001,
#          0.00596723, -0.09817229],
#        [-0.02940366, -0.11812167,  0.13482498, ..., -0.02998767,
#         -0.11269087, -0.05481352],
#        [-0.1474255 ,  0.01409372, -0.15391204, ...,  0.10552026,
#          0.12888193,  0.06586308]], dtype=float32)
